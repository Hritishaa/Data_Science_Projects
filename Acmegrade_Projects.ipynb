# %% [markdown]
# Batch Name:- DS January 2024
# Name:- Hritisha Sahota
# Registered Email ID:- hriti.sahota@gmail.com

# %% [markdown]
# Detection Of Parkinsons Disease

# %% [markdown]
# Parkinson's disease is a progressive disorder of the nervous system that affects several regions of the brain, most notably an area called the substantia nigra which controls balance and movement. The most common initial symptom of Parkinson's disease is tremors or shaking in a limb, especially when the body is at rest. The tremor usually begins on one side of the body, often in one hand, but it can also affect the arms, legs, feet, and face. Other characteristic symptoms of Parkinson's disease include stiffness in the limbs and chest, slow movement (bradykinesia), and postural instability. These symptoms tend to worsen over time. In this article, we present a system for detecting Parkinson's disease using the VGG-16 network and transfer learning. The system allows users to submit hand-drawn images of spirals and waves, which are then trained and predicted using the VGG-16 network. If the user is found to have Parkinson's disease, the system provides medical and therapeutic information for further diagnosis. The system is evaluated on its ability to detect different directions during drawing movements, and it achieves the best results for the X and Y directions. The experimental results show that the system has an accuracy of 92.6%."

# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

# %%
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
#model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
#model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
#model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
#model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
#model.add(BatchNormalization())

# 6th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
#model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
#model.add(BatchNormalization())

# 7th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
#model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
#model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 96)      2688
#
#  activation (Activation)     (None, 254, 254, 96)      0
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 96)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 256)     221440
#
#  activation_1 (Activation)   (None, 125, 125, 256)     0
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 256)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 384)       885120
#
#  activation_2 (Activation)   (None, 60, 60, 384)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 384)       0
#  g2D)
#
#  batch_normalization (Batch  (None, 30, 30, 384)       1536
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 384)       1327488
#
#  activation_3 (Activation)   (None, 28, 28, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 512)       1769984
#
#  activation_4 (Activation)   (None, 26, 26, 512)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 512)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 256)       1179904
#
#  activation_5 (Activation)   (None, 11, 11, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 9, 9, 256)         590080
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 4, 4, 256)         1024
#  chNormalization)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 4096)              16781312
#
#  activation_7 (Activation)   (None, 4096)              0
#
#  batch_normalization_2 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  dense_1 (Dense)             (None, 1000)              4097000
#
#  activation_8 (Activation)   (None, 1000)              0
#
#  batch_normalization_3 (Bat  (None, 1000)              4000
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 2002
#
#  activation_9 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 26879962 (102.54 MB)
# Trainable params: 26868490 (102.50 MB)
# Non-trainable params: 11472 (44.81 KB)
# _________________________________________________________________

# %%
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(5,5), strides=(2,2), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 126, 126, 96)      7296
#
#  activation_10 (Activation)  (None, 126, 126, 96)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 63, 63, 96)        0
#  g2D)
#
#  batch_normalization_4 (Bat  (None, 63, 63, 96)        384
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 59, 59, 256)       614656
#
#  activation_11 (Activation)  (None, 59, 59, 256)       0
#
#  max_pooling2d_6 (MaxPoolin  (None, 29, 29, 256)       0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 29, 29, 256)       1024
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 384)       885120
#
#  activation_12 (Activation)  (None, 27, 27, 384)       0
#
#  batch_normalization_6 (Bat  (None, 27, 27, 384)       1536
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 25, 25, 384)       1327488
#
#  activation_13 (Activation)  (None, 25, 25, 384)       0
#
#  batch_normalization_7 (Bat  (None, 25, 25, 384)       1536
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 23, 23, 256)       884992
#
#  activation_14 (Activation)  (None, 23, 23, 256)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 11, 11, 256)       1024
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_3 (Dense)             (None, 4096)              126881792
#
#  activation_15 (Activation)  (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  batch_normalization_9 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  activation_16 (Activation)  (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  batch_normalization_10 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dense_5 (Dense)             (None, 1000)              4097000
#
#  activation_17 (Activation)  (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  batch_normalization_11 (Ba  (None, 1000)              4000
#  tchNormalization)
#
#  dense_6 (Dense)             (None, 2)                 2002
#
#  activation_18 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 151523930 (578.02 MB)
# Trainable params: 151502794 (577.94 MB)
# Non-trainable params: 21136 (82.56 KB)
# _________________________________________________________________

# %%
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
#model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 6th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
#model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 7th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
#model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
#model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 254, 254, 96)      2688
#
#  activation_19 (Activation)  (None, 254, 254, 96)      0
#
#  max_pooling2d_8 (MaxPoolin  (None, 127, 127, 96)      0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 127, 127, 96)      384
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 125, 125, 256)     221440
#
#  activation_20 (Activation)  (None, 125, 125, 256)     0
#
#  max_pooling2d_9 (MaxPoolin  (None, 62, 62, 256)       0
#  g2D)
#
#  batch_normalization_13 (Ba  (None, 62, 62, 256)       1024
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 60, 60, 384)       885120
#
#  activation_21 (Activation)  (None, 60, 60, 384)       0
#
#  max_pooling2d_10 (MaxPooli  (None, 30, 30, 384)       0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 30, 30, 384)       1536
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 384)       1327488
#
#  activation_22 (Activation)  (None, 28, 28, 384)       0
#
#  batch_normalization_15 (Ba  (None, 28, 28, 384)       1536
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 26, 26, 512)       1769984
#
#  activation_23 (Activation)  (None, 26, 26, 512)       0
#
#  max_pooling2d_11 (MaxPooli  (None, 13, 13, 512)       0
#  ng2D)
#
#  batch_normalization_16 (Ba  (None, 13, 13, 512)       2048
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 11, 11, 256)       1179904
#
#  activation_24 (Activation)  (None, 11, 11, 256)       0
#
#  batch_normalization_17 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 9, 9, 256)         590080
#
#  activation_25 (Activation)  (None, 9, 9, 256)         0
#
#  max_pooling2d_12 (MaxPooli  (None, 4, 4, 256)         0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  activation_26 (Activation)  (None, 4096)              0
#
#  batch_normalization_19 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dense_8 (Dense)             (None, 1000)              4097000
#
#  activation_27 (Activation)  (None, 1000)              0
#
#  batch_normalization_20 (Ba  (None, 1000)              4000
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 2)                 2002
#
#  activation_28 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 26885978 (102.56 MB)
# Trainable params: 26871498 (102.51 MB)
# Non-trainable params: 14480 (56.56 KB)
# _________________________________________________________________

# %%
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# 6th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(2048))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.3))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_19 (Conv2D)          (None, 254, 254, 96)      2688
#
#  activation_29 (Activation)  (None, 254, 254, 96)      0
#
#  max_pooling2d_13 (MaxPooli  (None, 127, 127, 96)      0
#  ng2D)
#
#  batch_normalization_21 (Ba  (None, 127, 127, 96)      384
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 125, 125, 256)     221440
#
#  activation_30 (Activation)  (None, 125, 125, 256)     0
#
#  max_pooling2d_14 (MaxPooli  (None, 62, 62, 256)       0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 62, 62, 256)       1024
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 60, 60, 384)       885120
#
#  activation_31 (Activation)  (None, 60, 60, 384)       0
#
#  max_pooling2d_15 (MaxPooli  (None, 30, 30, 384)       0
#  ng2D)
#
#  batch_normalization_23 (Ba  (None, 30, 30, 384)       1536
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 384)       1327488
#
#  activation_32 (Activation)  (None, 28, 28, 384)       0
#
#  max_pooling2d_16 (MaxPooli  (None, 14, 14, 384)       0
#  ng2D)
#
#  batch_normalization_24 (Ba  (None, 14, 14, 384)       1536
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 512)       1769984
#
#  activation_33 (Activation)  (None, 12, 12, 512)       0
#
#  max_pooling2d_17 (MaxPooli  (None, 6, 6, 512)         0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 6, 6, 512)         2048
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 256)         1179904
#
#  activation_34 (Activation)  (None, 4, 4, 256)         0
#
#  max_pooling2d_18 (MaxPooli  (None, 2, 2, 256)         0
#  ng2D)
#
#  batch_normalization_26 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 2048)              2099200
#
#  activation_35 (Activation)  (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  batch_normalization_27 (Ba  (None, 2048)              8192
#  tchNormalization)
#
#  dense_11 (Dense)            (None, 1000)              2049000
#
#  activation_36 (Activation)  (None, 1000)              0
#
#  dropout_4 (Dropout)         (None, 1000)              0
#
#  batch_normalization_28 (Ba  (None, 1000)              4000
#  tchNormalization)
#
#  dense_12 (Dense)            (None, 2)                 2002
#
#  activation_37 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 9556570 (36.46 MB)
# Trainable params: 9546698 (36.42 MB)
# Non-trainable params: 9872 (38.56 KB)
# _________________________________________________________________

# %%
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(5,5), strides=(2,2), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(2,2), padding='valid'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(2,2), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

#Flatten
model.add(Flatten())

# 6th FC Layer
model.add(Dense(2048))
model.add(Activation('relu'))

# 7th FC Layer
model.add(Dense(1000))
model.add(Activation('relu'))

# 6th FC Layer
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 128, 128, 96)      7296
#
#  activation_38 (Activation)  (None, 128, 128, 96)      0
#
#  max_pooling2d_19 (MaxPooli  (None, 64, 64, 96)        0
#  ng2D)
#
#  batch_normalization_29 (Ba  (None, 64, 64, 96)        384
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 62, 62, 256)       221440
#
#  activation_39 (Activation)  (None, 62, 62, 256)       0
#
#  max_pooling2d_20 (MaxPooli  (None, 31, 31, 256)       0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 31, 31, 256)       1024
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 15, 15, 384)       885120
#
#  activation_40 (Activation)  (None, 15, 15, 384)       0
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 384)       590208
#
#  activation_41 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_29 (Conv2D)          (None, 12, 12, 256)       884992
#
#  activation_42 (Activation)  (None, 12, 12, 256)       0
#
#  max_pooling2d_21 (MaxPooli  (None, 6, 6, 256)         0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 9216)              0
#
#  dense_13 (Dense)            (None, 2048)              18876416
#
#  activation_43 (Activation)  (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1000)              2049000
#
#  activation_44 (Activation)  (None, 1000)              0
#
#  dense_15 (Dense)            (None, 2)                 2002
#
#  activation_45 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 23517882 (89.71 MB)
# Trainable params: 23517178 (89.71 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 128, 128, 96)      7296
#
#  activation_38 (Activation)  (None, 128, 128, 96)      0
#
#  max_pooling2d_19 (MaxPooli  (None, 64, 64, 96)        0
#  ng2D)
#
#  batch_normalization_29 (Ba  (None, 64, 64, 96)        384
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 62, 62, 256)       221440
#
#  activation_39 (Activation)  (None, 62, 62, 256)       0
#
#  max_pooling2d_20 (MaxPooli  (None, 31, 31, 256)       0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 31, 31, 256)       1024
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 15, 15, 384)       885120
#
#  activation_40 (Activation)  (None, 15, 15, 384)       0
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 384)       590208
#
#  activation_41 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_29 (Conv2D)          (None, 12, 12, 256)       884992
#
#  activation_42 (Activation)  (None, 12, 12, 256)       0
#
#  max_pooling2d_21 (MaxPooli  (None, 6, 6, 256)         0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 9216)              0
#
#  dense_13 (Dense)            (None, 2048)              18876416
#
#  activation_43 (Activation)  (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1000)              2049000
#
#  activation_44 (Activation)  (None, 1000)              0
#
#  dense_15 (Dense)            (None, 2)                 2002
#
#  activation_45 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 23517882 (89.71 MB)
# Trainable params: 23517178 (89.71 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %% [markdown]
# Project 2:- Movie Recommendation

# %%
import numpy as np
import pandas as pd
import json

# %%
import pandas as pd

# Read CSV file with error handling
try:
    meta = pd.read_csv('/content/Movie-Data-Set.csv', error_bad_lines=False)
except Exception as e:
    print("Error occurred:", e)
    meta = None

# Check if meta is properly defined
if meta is not None:
    # Selecting required columns
    meta = meta[['id', 'original_title', 'original_language', 'genres']]

    # Renaming 'id' column to 'movieId'
    meta = meta.rename(columns={'id':'movieId'})

    # Filtering for only English language movies
    meta = meta[meta['original_language'] == 'en']

    # Displaying the first few rows
    print(meta.head())
else:
    print("Error occurred during reading CSV. 'meta' is not defined.")
# Out:
# <ipython-input-15-e835d4d5c6f6>:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   meta = pd.read_csv('/content/Movie-Data-Set.csv', error_bad_lines=False)
# Error occurred: Error tokenizing data. C error: EOF inside string starting at row 43008
# Error occurred during reading CSV. 'meta' is not defined.

# %%
ratings = pd.read_csv('/content/ratings_small.csv')
ratings = ratings[['userId', 'movieId', 'rating']]
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %%
meta.movieId = pd.to_numeric(meta.movieId, errors='coerce')
ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-afcfdbc328e5> in <cell line: 1>()
# ----> 1 meta.movieId = pd.to_numeric(meta.movieId, errors='coerce')
#       2 ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')
#
# AttributeError: 'NoneType' object has no attribute 'movieId'

# %%
def parse_genres(genres_str):
    genres = json.loads(genres_str.replace('\'', '"'))

    genres_list = []
    for g in genres:
        genres_list.append(g['name'])

    return genres_list

meta['genres'] = meta['genres'].apply(parse_genres)

meta.head()

# %%
data = pd.merge(ratings, meta, on='movieId', how='inner')

data.head()

# %%
matrix = data.pivot_table(index='userId', columns='original_title', values='rating')

matrix.head(20)

# %%
GENRE_WEIGHT = 0.1

def pearsonR(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

def recommend(input_movie, matrix, n, similar_genre=True):
    input_genres = meta[meta['original_title'] == input_movie]['genres'].iloc(0)[0]

    result = []
    for title in matrix.columns:
        if title == input_movie:
            continue

        # rating comparison
        cor = pearsonR(matrix[input_movie], matrix[title])

        # genre comparison
        if similar_genre and len(input_genres) > 0:
            temp_genres = meta[meta['original_title'] == title]['genres'].iloc(0)[0]

            same_count = np.sum(np.isin(input_genres, temp_genres))
            cor += (GENRE_WEIGHT * same_count)

        if np.isnan(cor):
            continue
        else:
            result.append((title, '{:.2f}'.format(cor), temp_genres))

    result.sort(key=lambda r: r[1], reverse=True)

    return result[:n]

# %%
recommend_result = recommend('The Dark Knight', matrix, 10, similar_genre=True)

pd.DataFrame(recommend_result, columns = ['Title', 'Correlation', 'Genre'])
